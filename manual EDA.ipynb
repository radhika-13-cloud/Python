# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv(r'C:\Users\radhi\Downloads\archive (12)\AI_Impact_on_Jobs_2030.csv')

# %%
data
# Out:
#                 Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0          Security Guard           45795              28.0        Master's
# 1                     NaN          133355              20.0             PhD
# 2     Construction Worker          146216               2.0     High School
# 3                     NaN          136530              13.0             PhD
# 4                     NaN           70397              22.0     High School
# ...                   ...             ...               ...             ...
# 2995               Doctor          111319               6.0      Bachelor's
# 2996        UX Researcher           44363              29.0             PhD
# 2997       Data Scientist           61325              23.0        Master's
# 2998     Graphic Designer          110296               7.0             PhD
# 2999     Graphic Designer          123909              25.0             PhD
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job_Title                    2996 non-null   object
#  1   Average_Salary               3000 non-null   int64
#  2   Years_Experience             2998 non-null   float64
#  3   Education_Level              3000 non-null   object
#  4   AI_Exposure_Index            2998 non-null   float64
#  5   Tech_Growth_Factor           2998 non-null   float64
#  6   Automation_Probability_2030  2999 non-null   float64
#  7   Risk_Category                3000 non-null   object
#  8   Skill_1                      2998 non-null   float64
#  9   Skill_2                      3000 non-null   float64
#  10  Skill_3                      2999 non-null   float64
#  11  Skill_4                      2999 non-null   float64
# ...

# %%
data.describe()
# Out:
#        Average_Salary  Years_Experience  AI_Exposure_Index  \
# count     3000.000000       2998.000000        2998.000000
# mean     89372.279000         14.676451           0.501221
# std      34608.088767          8.741422           0.284082
# min      30030.000000          0.000000           0.000000
# 25%      58640.000000          7.000000           0.260000
# 50%      89318.000000         15.000000           0.500000
# 75%     119086.500000         22.000000           0.740000
# max     149798.000000         29.000000           1.000000
#
#        Tech_Growth_Factor  Automation_Probability_2030      Skill_1  \
# count         2998.000000                  2999.000000  2998.000000
# mean             0.995470                     0.501534     0.497155
# std              0.287628                     0.247917     0.287899
# min              0.500000                     0.050000     0.000000
# 25%              0.740000                     0.310000     0.240000
# ...

# %%
data.describe().T
# Out:
#                               count          mean           std       min  \
# Average_Salary               3000.0  89372.279000  34608.088767  30030.00
# Years_Experience             2998.0     14.676451      8.741422      0.00
# AI_Exposure_Index            2998.0      0.501221      0.284082      0.00
# Tech_Growth_Factor           2998.0      0.995470      0.287628      0.50
# Automation_Probability_2030  2999.0      0.501534      0.247917      0.05
# Skill_1                      2998.0      0.497155      0.287899      0.00
# Skill_2                      3000.0      0.497233      0.288085      0.00
# Skill_3                      2999.0      0.499366      0.288387      0.00
# Skill_4                      2999.0      0.503825      0.286980      0.00
# Skill_5                      3000.0      0.490270      0.285818      0.00
# Skill_6                      3000.0      0.499807      0.286050      0.00
# Skill_7                      3000.0      0.499160      0.288044      0.00
# ...

# %%
data.isnull().sum()
# Out:
# Job_Title                      4
# Average_Salary                 0
# Years_Experience               2
# Education_Level                0
# AI_Exposure_Index              2
# Tech_Growth_Factor             2
# Automation_Probability_2030    1
# Risk_Category                  0
# Skill_1                        2
# Skill_2                        0
# Skill_3                        1
# Skill_4                        1
# Skill_5                        0
# Skill_6                        0
# Skill_7                        0
# Skill_8                        1
# Skill_9                        1
# Skill_10                       0
# dtype: int64

# %%
missed_values=[fea for fea in data.columns if data[fea].isnull().sum()]
missed_values
#fea(finite element analysis)
# Out:
# ['Job_Title',
#  'Years_Experience',
#  'AI_Exposure_Index',
#  'Tech_Growth_Factor',
#  'Automation_Probability_2030',
#  'Skill_1',
#  'Skill_3',
#  'Skill_4',
#  'Skill_8',
#  'Skill_9']

# %%
len(missed_values)
# Out:
# 10

# %%
#check the missed values graphically  in each column
plt.figure(figsize=(9,6))
sns.heatmap(data.isnull(),cbar=True)
# Out:
# <Axes: >

# %%
data.isnull()
# Out:
#       Job_Title  Average_Salary  Years_Experience  Education_Level  \
# 0         False           False             False            False
# 1          True           False             False            False
# 2         False           False             False            False
# 3          True           False             False            False
# 4          True           False             False            False
# ...         ...             ...               ...              ...
# 2995      False           False             False            False
# 2996      False           False             False            False
# 2997      False           False             False            False
# 2998      False           False             False            False
# 2999      False           False             False            False
#
#       AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0                 False               False                        False
# ...

# %%
#segregate the data by numerical variable  and object variable
cat_col=[fea  for fea in data.columns if data[fea].dtype=='object']
cat_col
# Out:
# ['Job_Title', 'Education_Level', 'Risk_Category']

# %%
data
# Out:
#                 Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0          Security Guard           45795              28.0        Master's
# 1                     NaN          133355              20.0             PhD
# 2     Construction Worker          146216               2.0     High School
# 3                     NaN          136530              13.0             PhD
# 4                     NaN           70397              22.0     High School
# ...                   ...             ...               ...             ...
# 2995               Doctor          111319               6.0      Bachelor's
# 2996        UX Researcher           44363              29.0             PhD
# 2997       Data Scientist           61325              23.0        Master's
# 2998     Graphic Designer          110296               7.0             PhD
# 2999     Graphic Designer          123909              25.0             PhD
#
# ...

# %%
num_col=[fea  for fea in data.columns if data[fea].dtype!='object']
num_col
# Out:
# ['Average_Salary',
#  'Years_Experience',
#  'AI_Exposure_Index',
#  'Tech_Growth_Factor',
#  'Automation_Probability_2030',
#  'Skill_1',
#  'Skill_2',
#  'Skill_3',
#  'Skill_4',
#  'Skill_5',
#  'Skill_6',
#  'Skill_7',
#  'Skill_8',
#  'Skill_9',
#  'Skill_10']

# %%
numeric_data=data[num_col]
numeric_data
# Out:
#       Average_Salary  Years_Experience  AI_Exposure_Index  Tech_Growth_Factor  \
# 0              45795              28.0               0.18                1.28
# 1             133355              20.0               0.62                1.11
# 2             146216               2.0               0.86                1.18
# 3             136530              13.0               0.39                0.68
# 4              70397              22.0                NaN                1.46
# ...              ...               ...                ...                 ...
# 2995          111319               6.0               0.24                1.18
# 2996           44363              29.0               0.65                0.74
# 2997           61325              23.0               0.64                0.94
# 2998          110296               7.0               0.95                1.23
# 2999          123909              25.0               0.69                0.56
#
# ...

# %%
numeric_data=numeric_data.drop('Skill_1', axis=1)
numeric_data
# Out:
#       Average_Salary  Years_Experience  AI_Exposure_Index  Tech_Growth_Factor  \
# 0              45795              28.0               0.18                1.28
# 1             133355              20.0               0.62                1.11
# 2             146216               2.0               0.86                1.18
# 3             136530              13.0               0.39                0.68
# 4              70397              22.0                NaN                1.46
# ...              ...               ...                ...                 ...
# 2995          111319               6.0               0.24                1.18
# 2996           44363              29.0               0.65                0.74
# 2997           61325              23.0               0.64                0.94
# 2998          110296               7.0               0.95                1.23
# 2999          123909              25.0               0.69                0.56
#
# ...

# %%
numeric_data.describe().T
# Out:
#                               count          mean           std       min  \
# Average_Salary               3000.0  89372.279000  34608.088767  30030.00
# Years_Experience             2998.0     14.676451      8.741422      0.00
# AI_Exposure_Index            2998.0      0.501221      0.284082      0.00
# Tech_Growth_Factor           2998.0      0.995470      0.287628      0.50
# Automation_Probability_2030  2999.0      0.501534      0.247917      0.05
# Skill_2                      3000.0      0.497233      0.288085      0.00
# Skill_3                      2999.0      0.499366      0.288387      0.00
# Skill_4                      2999.0      0.503825      0.286980      0.00
# Skill_5                      3000.0      0.490270      0.285818      0.00
# Skill_6                      3000.0      0.499807      0.286050      0.00
# Skill_7                      3000.0      0.499160      0.288044      0.00
# Skill_8                      2999.0      0.502998      0.289757      0.00
# ...

# %%
sns.distplot(numeric_data['Years_Experience'])
# Out:
# <Axes: xlabel='Years_Experience', ylabel='Density'>

# %%
sns.histplot(numeric_data['Average_Salary'])
# Out:
# <Axes: xlabel='Average_Salary', ylabel='Count'>

# %%
plt.Figure(figsize=(10,8))
sns.heatmap(numeric_data.corr())
# Out:
# <Axes: >

# %%
cat_col
# Out:
# ['Average_Salary',
#  'Years_Experience',
#  'AI_Exposure_Index',
#  'Tech_Growth_Factor',
#  'Automation_Probability_2030',
#  'Skill_1',
#  'Skill_2',
#  'Skill_3',
#  'Skill_4',
#  'Skill_5',
#  'Skill_6',
#  'Skill_7',
#  'Skill_8',
#  'Skill_9',
#  'Skill_10']
